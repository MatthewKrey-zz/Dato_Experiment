# %%
import graphlab as gl

# %%
# Import and Parse Data 

url = 'http://s3.amazonaws.com/dato-datasets/millionsong/song_data.csv'
songs = gl.SFrame.read_csv(url)
# Out:
# [INFO] 1450634523 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /Users/matthewkrey/anaconda2/envs/dato-env/lib/python2.7/site-packages/certifi/cacert.pem
# 1450634523 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to matthew.krey@flatironschool.com and will expire on December 14, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-53048 - Server binary: /Users/matthewkrey/anaconda2/envs/dato-env/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1450634523.log
# [INFO] GraphLab Server Version: 1.7.1
# ...

# %%
# Visualizations 

songs.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:56924/index.html
# Opening Canvas in default web browser.

# %%
# Computation on Columns

songs['year'].mean()
# Out:
# 1030.3256520000045

# %%
# Transforming Columns 

songs['num_words'] = songs['title'].apply(lambda x:len(x.split(' ')))

# %%
# Aggregations 

songs.groupby('artist_name', {'total': gl.aggregate.COUNT})
# Out:
# Columns:
# 	artist_name	str
# 	total	int
#
# Rows: 72664
#
# Data:
# +-------------------------------+-------+
# |          artist_name          | total |
# +-------------------------------+-------+
# |   Gary Lewis & The Playboys   |   45  |
# |           The Dells           |   54  |
# | Martha Argerich/Kathia Bun... |   1   |
# | S.S featuring Jp_ Mar Da C... |   1   |
# |       Big L / Kool G Rap      |   1   |
# |         Lil Wayne / BG        |   1   |
# |         Pete Kingwell         |   1   |
# |    The High Noon Orchestra    |   1   |
# |           Doormouse           |   27  |
# | Richard Vission & Static A... |   2   |
# +-------------------------------+-------+
# [72664 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
# Create Models 

housing = 'http://s3.amazonaws.com/dato-datasets/regression/Housing.csv'
x = gl.SFrame.read_csv(housing)
m = gl.linear_regression.create(x, target='price')
# Out:
# PROGRESS: Downloading http://s3.amazonaws.com/dato-datasets/regression/Housing.csv to /var/tmp/graphlab-matthewkrey/51491/7fbf73de-63ba-4a51-9ec5-8246d2f7649f.csv
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/regression/Housing.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.011164 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,int,int,int,int,int,str,str,str,str,str,int,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/regression/Housing.csv
# PROGRESS: Parsing completed. Parsed 546 lines in 0.010332 secs.
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
# ...

# %%
# Specify options with csv read 

usage_data = gl.SFrame.read_csv("http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt",
                               header = False,
                               delimiter = '\t',
                               column_type_hints = {'X3': int})
# Out:
# PROGRESS: Downloading http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt to /var/tmp/graphlab-matthewkrey/51491/2895e955-659f-4be4-89f2-134a79000659.txt
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt
# PROGRESS: Parsing completed. Parsed 100 lines in 0.760688 secs.
# PROGRESS: Read 844838 lines. Lines per second: 893193
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt
# PROGRESS: Parsing completed. Parsed 2000000 lines in 1.50895 secs.

# %%
songs
# Out:
# Columns:
# 	song_id	str
# 	title	str
# 	release	str
# 	artist_name	str
# 	year	int
#
# Rows: 1000000
#
# Data:
# +--------------------+-------------------------------+
# |      song_id       |             title             |
# +--------------------+-------------------------------+
# | SOQMMHC12AB0180CB8 |          Silent Night         |
# | SOVFVAK12A8C1350D9 |          Tanssi vaan          |
# | SOGTUKN12AB017F4F1 |       No One Could Ever       |
# | SOBNYVR12A8C13558C |         Si Vos Querés         |
# | SOHSBXH12A8C13B0DF |        Tangle Of Aspens       |
# | SOZVAPQ12A8C13B63C | Symphony No. 1 G minor "Si... |
# | SOQVRHI12A6D4FB2D7 |        We Have Got Love       |
# | SOEYRFT12AB018936C |       2 Da Beat Ch'yall       |
# | SOPMIYT12A6D4F851E |            Goodbye            |
# | SOJCFMH12A8C13B0C2 |   Mama_ mama can't you see ?  |
# +--------------------+-------------------------------+
# +-------------------------------+-------------------------------+------+
# ...

# %%
usage_data
# Out:
# Columns:
# 	X1	str
# 	X2	str
# 	X3	int
#
# Rows: 2000000
#
# Data:
# +-------------------------------+--------------------+----+
# |               X1              |         X2         | X3 |
# +-------------------------------+--------------------+----+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 | 1  |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B | 2  |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 | 1  |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D | 1  |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 | 1  |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E | 5  |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B | 1  |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 | 1  |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 | 1  |
# | b80344d063b5ccb3212f76538f... | SOHQWYZ12A6D4FA701 | 1  |
# +-------------------------------+--------------------+----+
# [2000000 rows x 3 columns]
# ...

# %%
# Rename SFrame columns

usage_data.rename({'X1':'user_id', 'X2':'song_id', 'X3':'listen_count'})
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
#
# Rows: 2000000
#
# Data:
# +-------------------------------+--------------------+--------------+
# |            user_id            |      song_id       | listen_count |
# +-------------------------------+--------------------+--------------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |
# | b80344d063b5ccb3212f76538f... | SOFRQTD12A81C233C0 |      1       |
# ...

# %%
# Column Selection & Manipulation with lambdas 

songs['year'] = songs['year'].apply(lambda x: None if x == 0 else x)
songs.head(5)
# Out:
# Columns:
# 	song_id	str
# 	title	str
# 	release	str
# 	artist_name	str
# 	year	int
#
# Rows: 5
#
# Data:
# +--------------------+-------------------+-------------------------------+
# |      song_id       |       title       |            release            |
# +--------------------+-------------------+-------------------------------+
# | SOQMMHC12AB0180CB8 |    Silent Night   |     Monster Ballads X-Mas     |
# | SOVFVAK12A8C1350D9 |    Tanssi vaan    |          Karkuteillä          |
# | SOGTUKN12AB017F4F1 | No One Could Ever |             Butter            |
# | SOBNYVR12A8C13558C |   Si Vos Querés   |            De Culo            |
# | SOHSBXH12A8C13B0DF |  Tangle Of Aspens | Rene Ablaze Presents Winte... |
# +--------------------+-------------------+-------------------------------+
# +------------------+------+
# |   artist_name    | year |
# +------------------+------+
# | Faster Pussy cat | 2003 |
# | Karkkiautomaatti | 1995 |
# |  Hudson Mohawke  | 2006 |
# ...

# %%
# Apply a function across multiple columns. Count number of times the word 'love' is used in the title and artist columns.

songs['love_count'] = songs[['title', 'artist_name']].apply(
    lambda row: sum(x.lower().split(' ').count('love') for x in row.values()))
songs.topk('love_count', k = 5)
# Out:
# Columns:
# 	song_id	str
# 	title	str
# 	release	str
# 	artist_name	str
# 	year	int
# 	love_count	int
#
# Rows: 5
#
# Data:
# +--------------------+-------------------------------+
# |      song_id       |             title             |
# +--------------------+-------------------------------+
# | SOMYDCX12A8AE4836B | The Love Story (Part 1) In... |
# | SONXAVM12AB017AA1D |          Document 15          |
# | SOAWJOC12A8C1367A7 |       Black Black Window      |
# | SODDGPO12AB0181ADB |       Flower In The Mind      |
# | SOXAVWF12A8AE4922C |           One Piece           |
# +--------------------+-------------------------------+
# +-------------------------------+-------------------------------+------+------------+
# |            release            |          artist_name          | year | love_count |
# +-------------------------------+-------------------------------+------+------------+
# |      Skid Row / 34 Hours      |            Skid Row           | None |     4      |
# ...

# %%
# Quick summaries of columns with .sketch_summary() 
songs['year'].sketch_summary()
songs['artist_name'].sketch_summary()
songs['title'].sketch_summary()
# Out:
# +------------------+---------+----------+
# |       item       |  value  | is exact |
# +------------------+---------+----------+
# |      Length      | 1000000 |   Yes    |
# | # Missing Values |    0    |   Yes    |
# | # unique values  |  700922 |    No    |
# +------------------+---------+----------+
#
# Most frequent items:
# +-------+-------+----------+-------+-----------+------+--------------+------+
# | value | Intro | Untitled | Outro | Interlude | Home | Silent Night | Time |
# +-------+-------+----------+-------+-----------+------+--------------+------+
# | count |  1512 |   419    |  347  |    300    | 236  |     218      | 208  |
# +-------+-------+----------+-------+-----------+------+--------------+------+
# +---------+---------+------------+
# | Hold On | Tonight | Summertime |
# +---------+---------+------------+
# |   200   |   183   |    178     |
# +---------+---------+------------+

# %%
# Visualizations 

songs['year'].show()
songs['title'].show()
songs['artist_name'].show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:59074/index.html
# Opening Canvas in default web browser.
# Canvas is updated and available in a tab in the default browser.
# Canvas is updated and available in a tab in the default browser.

# %%
# Go Bananas... ENGAGE!

usage_data = gl.SFrame.read_csv("http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt",
                               header = False,
                               delimiter = '\t',
                               column_type_hints = {'X3': int})

usage_data.rename({'X1':'user_id', 'X2':'song_id', 'X3':'listen_count'}) 

reasonable_usage = usage_data[(usage_data['listen_count'] >= 10) & (usage_data['listen_count'] <= 500)]
len(reasonable_usage)
# Out:
# PROGRESS: Downloading http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt to /var/tmp/graphlab-matthewkrey/53048/30eb1e11-a2a0-47c1-9136-0ddcdef0ee4d.txt
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt
# PROGRESS: Parsing completed. Parsed 100 lines in 0.872408 secs.
# PROGRESS: Read 844838 lines. Lines per second: 760923
# PROGRESS: Finished parsing file http://s3.amazonaws.com/dato-datasets/millionsong/10000.txt
# PROGRESS: Parsing completed. Parsed 2000000 lines in 1.71155 secs.
# 114026

# %%
songs.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:52824/index.html
# Opening Canvas in default web browser.

# %%
# Filter duplicate song_ids 

other_cols = songs.column_names()
other_cols.remove('song_id')
aggregate_list = [gl.aggregate.SELECT_ONE(i) for i in other_cols]
unique_songs = songs.groupby('song_id', dict(zip(other_cols, aggregate_list)))

# %%
# What songs have the highest play count? Correctly group each song and aggregate its listen count. Join the result to the song metadata to see the song titles. 

tmp = usage_data.groupby(['song_id'], {'total_listens': gl.aggregate.SUM('listen_count'),
                                      'num_unique_users': gl.aggregate.COUNT('user_id')})
tmp.join(songs, ['song_id']).topk('total_listens')
# Out:
# Columns:
# 	song_id	str
# 	num_unique_users	int
# 	total_listens	int
# 	title	str
# 	release	str
# 	artist_name	str
# 	year	int
#
# Rows: 10
#
# Data:
# +--------------------+------------------+---------------+
# |      song_id       | num_unique_users | total_listens |
# +--------------------+------------------+---------------+
# | SOBONKR12A58A7A7E0 |       6412       |     54136     |
# | SOAUWYT12A81C206F1 |       7032       |     49253     |
# | SOSXLTC12AF72A7F54 |       6145       |     41418     |
# | SOEGIYH12A6D4FC0E3 |       5385       |     31153     |
# | SOFRQTD12A81C233C0 |       8277       |     31036     |
# | SOAXGDH12A8C13F8A1 |       6949       |     26663     |
# | SONYKOW12AB01849C9 |       5841       |     22100     |
# | SOPUCYA12A8C13A694 |       3526       |     21019     |
# | SOUFTBI12AB0183F65 |       2887       |     19645     |
# | SOVDSJC12A58A7A271 |       2866       |     18309     |
# +--------------------+------------------+---------------+
# ...

# %%
# Translate listen_count into a rating. The problem with the above data is that users that listened to a song a lot would skew recommendations if fed to a recommender algorithm.

s = usage_data['listen_count'].sketch_summary()
import numpy
buckets = numpy.linspace(s.quantile(.005), s.quantile(.995), 5)

def bucketize(x):
    cur_bucket = 0
    for i in range(0,5):
        cur_bucket +=1 
        if x <= buckets[i]:
            break
    return cur_bucket

usage_data['rating'] = usage_data['listen_count'].apply(bucketize)
usage_data
# Out:
# Columns:
# 	user_id	str
# 	song_id	str
# 	listen_count	int
# 	rating	int
#
# Rows: 2000000
#
# Data:
# +-------------------------------+--------------------+--------------+--------+
# |            user_id            |      song_id       | listen_count | rating |
# +-------------------------------+--------------------+--------------+--------+
# | b80344d063b5ccb3212f76538f... | SOAKIMP12A8C130995 |      1       |   1    |
# | b80344d063b5ccb3212f76538f... | SOBBMDR12A8C13253B |      2       |   2    |
# | b80344d063b5ccb3212f76538f... | SOBXHDL12A81C204C0 |      1       |   1    |
# | b80344d063b5ccb3212f76538f... | SOBYHAJ12A6701BF1D |      1       |   1    |
# | b80344d063b5ccb3212f76538f... | SODACBL12A8C13C273 |      1       |   1    |
# | b80344d063b5ccb3212f76538f... | SODDNQT12A6D4F5F7E |      5       |   2    |
# | b80344d063b5ccb3212f76538f... | SODXRTY12AB0180F3B |      1       |   1    |
# | b80344d063b5ccb3212f76538f... | SOFGUAY12AB017B0A8 |      1       |   1    |
# ...

# %%
# SArrays are strongly-typed, BUT they can hold values of any type supported by SArrays, including themselves!!

albums = songs.groupby(['release', 'artist_name'], {'tracks': gl.aggregate.CONCAT('title'),
                                                   'years': gl.aggregate.CONCAT('year')})
albums
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	tracks	list
# 	years	list
#
# Rows: 230560
#
# Data:
# +-------------------------------+-------------------------------+
# |          artist_name          |            release            |
# +-------------------------------+-------------------------------+
# |          Veruca Salt          |     Eight Arms To Hold You    |
# |  Les Compagnons De La Chanson | Heritage - Le Chant De Mal... |
# | Nelly / Fat Joe / Young Tr... |             Sweat             |
# |           The Grouch          |       My Baddest B*tches      |
# |         Ozzy Osbourne         | Diary of a madman / Bark a... |
# |        Peter Hunnigale        |      Reggae Hits Vol. 32      |
# |         Burning Spear         |      Studio One Classics      |
# |              Bond             |        New Classix 2008       |
# | Lee Coombs feat. Katherine... |            Control            |
# |         Stevie Wonder         |    Songs In The Key Of Life   |
# ...

# %%
 albums[0]
# Out:
# {'artist_name': 'Veruca Salt',
#  'release': 'Eight Arms To Hold You',
#  'tracks': ['With David Bowie',
#   'One Last Time',
#   'Awesome',
#   'The Morning Sad',
#   "Don't Make Me Prove It",
#   'Straight',
#   'Stoneface',
#   'Earthcrosser',
#   'Benjamin',
#   'Volcano Girls',
#   'Sound Of The Bell',
#   'Shutterbug',
#   'Loneliness Is Worse',
#   'Venus Man Trap'],
#  'years': [1997,
#   1997,
#   1997,
#   1997,
#   1997,
#   1994,
#   1997,
#   1997,
#   1997,
#   1997,
#   1997,
#   1997,
#   1997,
#   1997]}

# %%
# Rewrite 'tracks' column to have dictionaries with keys are the years and the values are the lists of tracks

albums = songs.groupby(['release', 'artist_name', 'year'], {'tracks': gl.aggregate.CONCAT('title')})
albums = albums.unstack(column=['year','tracks'], new_column_name='track_dict')
albums
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	track_dict	dict
#
# Rows: 230560
#
# Data:
# +-------------------------------+-------------------------------+
# |          artist_name          |            release            |
# +-------------------------------+-------------------------------+
# |          Veruca Salt          |     Eight Arms To Hold You    |
# |  Les Compagnons De La Chanson | Heritage - Le Chant De Mal... |
# | Nelly / Fat Joe / Young Tr... |             Sweat             |
# |           The Grouch          |       My Baddest B*tches      |
# |         Ozzy Osbourne         | Diary of a madman / Bark a... |
# |        Peter Hunnigale        |      Reggae Hits Vol. 32      |
# |         Burning Spear         |      Studio One Classics      |
# |              Bond             |        New Classix 2008       |
# | Lee Coombs feat. Katherine... |            Control            |
# |         Stevie Wonder         |    Songs In The Key Of Life   |
# ...

# %%
albums['num_years'] = albums['track_dict'].item_length()
albums['num_years'].show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:52824/index.html
# Opening Canvas in default web browser.

# %%
# Some more manipulation 

albums['track_list'] = albums['track_dict'].dict_values()
albums
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	track_dict	dict
# 	num_years	int
# 	track_list	list
#
# Rows: 230560
#
# Data:
# +-------------------------------+-------------------------------+
# |          artist_name          |            release            |
# +-------------------------------+-------------------------------+
# |          Veruca Salt          |     Eight Arms To Hold You    |
# |  Les Compagnons De La Chanson | Heritage - Le Chant De Mal... |
# | Nelly / Fat Joe / Young Tr... |             Sweat             |
# |           The Grouch          |       My Baddest B*tches      |
# |         Ozzy Osbourne         | Diary of a madman / Bark a... |
# |        Peter Hunnigale        |      Reggae Hits Vol. 32      |
# |         Burning Spear         |      Studio One Classics      |
# |              Bond             |        New Classix 2008       |
# | Lee Coombs feat. Katherine... |            Control            |
# ...

# %%
# Recover track_list. Convert list of lists into single list using itertools. 
# itertools are super interesting https://docs.python.org/2/library/itertools.html 

import itertools
albums['track_list'] = albums['track_list'].apply(lambda x: list(itertools.chain(*x)))
albums
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	track_dict	dict
# 	num_years	int
# 	track_list	list
#
# Rows: 230560
#
# Data:
# +-------------------------------+-------------------------------+
# |          artist_name          |            release            |
# +-------------------------------+-------------------------------+
# |          Veruca Salt          |     Eight Arms To Hold You    |
# |  Les Compagnons De La Chanson | Heritage - Le Chant De Mal... |
# | Nelly / Fat Joe / Young Tr... |             Sweat             |
# |           The Grouch          |       My Baddest B*tches      |
# |         Ozzy Osbourne         | Diary of a madman / Bark a... |
# |        Peter Hunnigale        |      Reggae Hits Vol. 32      |
# |         Burning Spear         |      Studio One Classics      |
# |              Bond             |        New Classix 2008       |
# | Lee Coombs feat. Katherine... |            Control            |
# ...

# %%
# Filter elements from within a list or dictionary 

albums['track_dict'] = albums['track_dict'].dict_trim_by_keys([1994, 1999])
albums
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	track_dict	dict
# 	num_years	int
# 	track_list	list
#
# Rows: 230560
#
# Data:
# +-------------------------------+-------------------------------+
# |          artist_name          |            release            |
# +-------------------------------+-------------------------------+
# |          Veruca Salt          |     Eight Arms To Hold You    |
# |  Les Compagnons De La Chanson | Heritage - Le Chant De Mal... |
# | Nelly / Fat Joe / Young Tr... |             Sweat             |
# |           The Grouch          |       My Baddest B*tches      |
# |         Ozzy Osbourne         | Diary of a madman / Bark a... |
# |        Peter Hunnigale        |      Reggae Hits Vol. 32      |
# |         Burning Spear         |      Studio One Classics      |
# |              Bond             |        New Classix 2008       |
# | Lee Coombs feat. Katherine... |            Control            |
# ...

# %%
# Filter and find elements in dictionaries 

albums[albums['track_dict'].dict_has_any_keys(1965)]
# Out:
# Columns:
# 	artist_name	str
# 	release	str
# 	track_dict	dict
# 	num_years	int
# 	track_list	list
#
# Rows: Unknown
#
# Data:
# +----------------------------+-------------------------------+
# |        artist_name         |            release            |
# +----------------------------+-------------------------------+
# | Jr. Walker & The All Stars | The Motown Story: The Sixties |
# |        The Seekers         | The Best Sixties Album In ... |
# | Jr. Walker & The All Stars | Sparks Present Motown Made... |
# |          The Who           |           Who's Next          |
# |        Bobby Vinton        |    The Best Of Bobby Vinton   |
# |     Righteous Brothers     |         The Collection        |
# |       Little Milton        |          Chess Blues          |
# |          The Who           |          Singles Box          |
# |       Dionne Warwick       |           Here I Am           |
# |        Albert Ayler        | Nuits De La Fondation Maeg... |
# ...

# %%
# Can convert into table with one column with all values packed into a list 

big_list = albums.pack_columns(albums.column_names())
big_list.rename({'X1': 'BIG LIST'})
# Out:
# Columns:
# 	BIG LIST	list
#
# Rows: 230560
#
# Data:
# +-------------------------------+
# |            BIG LIST           |
# +-------------------------------+
# | [Veruca Salt, Eight Arms T... |
# | [Les Compagnons De La Chan... |
# | [Nelly / Fat Joe / Young T... |
# | [The Grouch, My Baddest B*... |
# | [Ozzy Osbourne, Diary of a... |
# | [Peter Hunnigale, Reggae H... |
# | [Burning Spear, Studio One... |
# | [Bond, New Classix 2008, {... |
# | [Lee Coombs feat. Katherin... |
# | [Stevie Wonder, Songs In T... |
# +-------------------------------+
# [230560 rows x 1 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.
